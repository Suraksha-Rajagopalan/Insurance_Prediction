# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\araku\Downloads\ML\DataScience\archive (1)\Health_insurance.csv")
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
#Checking for null values
import numpy as np

print(np.sum(data.isnull())) #there is no null value in the dataset
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
#Visualising the null values using heatmap

sn.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
#Checking for outliers 

sn.boxplot(data)
# Out:
# <Axes: >

# %%
#understanding the distributo=ion of the data

plt.scatter(data['age'], data['charges'], color = 'black')
plt.xlabel('AGE')
plt.ylabel('CHARGES')
plt.title('AGE vs CHARGES')
# Out:
# Text(0.5, 1.0, 'AGE vs CHARGES')

# %%
#understanding the distributo=ion of the data

plt.scatter(data['sex'], data['charges'], color = 'black')
plt.xlabel('SEX')
plt.ylabel('CHARGES')
plt.title('SEX vs CHARGES')
# Out:
# Text(0.5, 1.0, 'SEX vs CHARGES')

# %%
#understanding the distributo=ion of the data

plt.scatter(data['bmi'], data['charges'], color = 'black')
plt.xlabel('BMI')
plt.ylabel('CHARGES')
plt.title('BMI vs CHARGES')
# Out:
# Text(0.5, 1.0, 'BMI vs CHARGES')

# %%
#understanding the distributo=ion of the data

plt.scatter(data['children'], data['charges'], color = 'black')
plt.xlabel('Children')
plt.ylabel('CHARGES')
plt.title('Children vs CHARGES')
# Out:
# Text(0.5, 1.0, 'Children vs CHARGES')

# %%
#understanding the distributo=ion of the data

plt.scatter(data['smoker'], data['charges'], color = 'black')
plt.xlabel('Smoker')
plt.ylabel('CHARGES')
plt.title('Smoker vs CHARGES')
# Out:
# Text(0.5, 1.0, 'Smoker vs CHARGES')

# %%
#understanding the distributo=ion of the data

plt.scatter(data['region'], data['charges'], color = 'black')
plt.xlabel('Region')
plt.ylabel('CHARGES')
plt.title('Region vs CHARGES')
# Out:
# Text(0.5, 1.0, 'Region vs CHARGES')

# %%
#Separating numeric and non numeric columns

numeric = ['bmi', 'age', 'charges', 'children']
non_numeric = ['smoker', 'region', 'sex']

# %%
#Correlation PLot 

sn.heatmap(data[numeric].corr(), annot=True)
# Out:
# <Axes: >

# %%
from sklearn import preprocessing 
  
# label_encoder object knows  
# how to understand word labels. 
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column that are non numeric.
for i in non_numeric:
    data[i]= label_encoder.fit_transform(data[i]) 

#Final dataframe
data.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       3  16884.92400
# 1   18    1  33.770         1       0       2   1725.55230
# 2   28    1  33.000         3       0       2   4449.46200
# 3   33    1  22.705         0       0       1  21984.47061
# 4   32    1  28.880         0       0       1   3866.85520

# %% [markdown]
# <h3>What is Outlier?</h3>
# An Outlier is a data item/object that deviates significantly from the rest of the (so-called normal) objects. Identifying outliers is important in statistics and data analysis because they can have a significant impact on the results of statistical analyses. The analysis for outlier detection is referred to as outlier mining.
#
# Outliers can skew the mean (average) and affect measures of central tendency, as well as influence the results of tests of statistical significance.
#
# <h3>How Outliers are Caused?</h3>
# Outliers can be caused by a variety of factors, and they often result from genuine variability in the data or from errors in data collection, measurement, or recording. Some common causes of outliers are:
#
# - Measurement errors: Errors in data collection or measurement processes can lead to outliers.
# - Sampling errors: In some cases, outliers can arise due to issues with the sampling process.
# - Natural variability: Inherent variability in certain phenomena can also lead to outliers. Some systems may exhibit extreme values due to the nature of the process being studied.
# - Data entry errors: Human errors during data entry can introduce outliers.
# - Experimental errors: In experimental settings, anomalies may occur due to uncontrolled factors, equipment malfunctions, or unexpected events.
# - Sampling from multiple populations: Data is inadvertently combined from multiple populations with different characteristics.
# - Intentional outliers: Outliers are introduced intentionally to test the robustness of statistical methods.
# <h3>Outlier Detection And Removal</h3>
# Here pandas data frame is used for a more realistic approach as real-world projects need to detect the outliers that arose during the data analysis step, the same approach can be used on lists and series-type objects.

# %%
# Boxplot to visualize outliers
sn.boxplot(data['bmi'])
plt.show()

# Calculating Q1 (25th percentile) and Q3 (75th percentile)
Q1 = data['bmi'].quantile(0.25)
Q3 = data['bmi'].quantile(0.75)
IQR = Q3 - Q1

# Defining the lower and upper limits for outliers
lower_limit_bmi = Q1 - 1.5 * IQR
upper_limit_bmi = Q3 + 1.5 * IQR

print(f"Lower limit for BMI outliers: {lower_limit_bmi}")
print(f"Upper limit for BMI outliers: {upper_limit_bmi}")
# Out:
# Lower limit for BMI outliers: 13.7
# Upper limit for BMI outliers: 47.290000000000006

# %%
# Boxplot to visualize outliers
sn.boxplot(data['charges'])
plt.show()

# Calculating Q1 (25th percentile) and Q3 (75th percentile)
Q1 = data['charges'].quantile(0.25)
Q3 = data['charges'].quantile(0.75)
IQR = Q3 - Q1

# Defining the lower and upper limits for outliers
lower_limit_charges = Q1 - 1.5 * IQR
upper_limit_charges = Q3 + 1.5 * IQR

print(f"Lower limit for BMI outliers: {lower_limit_charges}")
print(f"Upper limit for BMI outliers: {upper_limit_charges}")
# Out:
# Lower limit for BMI outliers: -13109.1508975
# Upper limit for BMI outliers: 34489.350562499996

# %%
# Identifying outliers based on the calculated limits
charges_outliers = np.where((data['charges'] > lower_limit_charges) & (data['charges'] < lower_limit_charges))
bmi_outliers = np.where((data['bmi'] < lower_limit_bmi) | (data['bmi'] > upper_limit_bmi))

# Combine indices of both outliers
combined_outliers = np.union1d(charges_outliers[0], bmi_outliers[0])

# Dropping the combined outliers from the original DataFrame
data_no_outliers = data.drop(combined_outliers)

# Reassign the cleaned DataFrame back to the original variable
data = data_no_outliers

# Scatter plot without outliers
fig, ax_no_outliers = plt.subplots(figsize=(6, 4))
ax_no_outliers.scatter(data['bmi'], data['charges'])
ax_no_outliers.set_xlabel('BMI')
ax_no_outliers.set_ylabel('Charges')
ax_no_outliers.set_title('Scatter Plot without Outliers')
plt.show()

# %%
#Checking the correlation plot 

sn.heatmap(data.corr(), annot=True)
# Out:
# <Axes: >

# %%
#Doing a Linear Regression with Somker and Charges 

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score


# Define X and Y
X = data[['smoker']]  # Independent variable
Y = data['charges']   # Dependent variable

# Split the data into training and testing sets 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Create a linear regression model
model_lr_c = LinearRegression()

# Fit the model to the training data
model_lr_c.fit(X_train, Y_train)

# Predict on the test set
Y_pred = model_lr_c.predict(X_test)

# Print the coefficients
print(f"Coefficient: {model_lr_c.coef_[0]}")
print(f"Intercept: {model_lr_c.intercept_}")

# Evaluate the model
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)
print(f"Mean Squared Error: {mse}")
print(f"R^2 Score: {r2}")

# Scatter plot and regression line
plt.figure(figsize=(10, 6))
plt.scatter(X_test, Y_test, color='blue', label='Actual charges')
plt.plot(X_test, Y_pred, color='red', linewidth=2, label='Fitted line')
plt.xlabel('Smoker')
plt.ylabel('Charges')
plt.title('Linear Regression: Smoker vs Charges')
plt.legend()
plt.show()
# Out:
# Coefficient: 23161.538199696974
# Intercept: 8430.459582046153
# Mean Squared Error: 53863957.12861519
# R^2 Score: 0.6363845412415445

# %%
# Define features (X) and target (Y)
X = data[['age', 'sex', 'bmi', 'smoker', 'children', 'region']]
Y = data['charges']

# Split the data into training and testing sets (optional but recommended)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Create a linear regression model
model_lr = LinearRegression()

# Fit the model to the training data
model_lr.fit(X_train, Y_train)

# Predict on the test set
Y_pred = model_lr.predict(X_test)

# Print the coefficients
coefficients = pd.DataFrame(model_lr.coef_.reshape(-1, 1), X.columns, columns=['Coefficient'])
print(coefficients)
print(f"Intercept: {model_lr.intercept_}")

# Evaluate the model
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)
print(f"Mean Squared Error: {mse}")
print(f"R^2 Score: {r2}")

# Scatter plot of actual vs predicted values
plt.figure(figsize=(10, 6))
plt.scatter(Y_test, Y_pred, color='blue', edgecolor='k', alpha=0.7)
plt.plot([Y_test.min(), Y_test.max()], [Y_test.min(), Y_test.max()], color='red', linewidth=2)
plt.xlabel('Actual Charges')
plt.ylabel('Predicted Charges')
plt.title('Actual vs Predicted Charges')
plt.show()
# Out:
#            Coefficient
# age         256.378910
# sex        -117.008444
# bmi         328.846570
# smoker    23621.635961
# children    527.179077
# region     -450.909072
# Intercept: -11547.603228709871
# Mean Squared Error: 34513457.16860573
# R^2 Score: 0.7670125399116677

# %%
from sklearn.ensemble import GradientBoostingRegressor

# Create a Gradient Boosting Regressor model
model = GradientBoostingRegressor(n_estimators=100, random_state=42)

# Fit the model to the training data
model.fit(X_train, Y_train)

# Predict on the test set
Y_pred = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)
print(f"Mean Squared Error: {mse}")
print(f"R^2 Score: {r2}")

# Feature importance
feature_importances = pd.DataFrame(model.feature_importances_, index=X.columns, columns=['Importance']).sort_values('Importance', ascending=False)
print(feature_importances)

# Scatter plot of actual vs predicted values
plt.figure(figsize=(10, 6))
plt.scatter(Y_test, Y_pred, color='blue', edgecolor='k', alpha=0.7)
plt.plot([Y_test.min(), Y_test.max()], [Y_test.min(), Y_test.max()], color='red', linewidth=2)
plt.xlabel('Actual Charges')
plt.ylabel('Predicted Charges')
plt.title('Actual vs Predicted Charges')
plt.show()
# Out:
# Mean Squared Error: 20372778.016568188
# R^2 Score: 0.862470983945901
#           Importance
# smoker      0.679761
# bmi         0.177076
# age         0.123576
# children    0.013048
# region      0.005787
# sex         0.000752

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Create a Random Forest Regressor model
model_rf = RandomForestRegressor(n_estimators=100, random_state=42)

# Fit the model to the training data
model_rf.fit(X_train, Y_train)

# Predict on the test set
Y_pred = model_rf.predict(X_test)

# Evaluate the model
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)
print(f"Mean Squared Error: {mse}")
print(f"R^2 Score: {r2}")

# Feature importance
feature_importances = pd.DataFrame(model_rf.feature_importances_, index=X.columns, columns=['Importance']).sort_values('Importance', ascending=False)
print(feature_importances)

# Scatter plot of actual vs predicted values
plt.figure(figsize=(10, 6))
plt.scatter(Y_test, Y_pred, color='blue', edgecolor='k', alpha=0.7)
plt.plot([Y_test.min(), Y_test.max()], [Y_test.min(), Y_test.max()], color='red', linewidth=2)
plt.xlabel('Actual Charges')
plt.ylabel('Predicted Charges')
plt.title('Actual vs Predicted Charges')
plt.show()
# Out:
# Mean Squared Error: 25329094.340718348
# R^2 Score: 0.8290127434075268
#           Importance
# smoker      0.612136
# bmi         0.202729
# age         0.142387
# children    0.023117
# region      0.014174
# sex         0.005456

# %%
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data into training and testing sets (optional but recommended)
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y, test_size=0.2, random_state=42)

# Define the SVR model
svr = SVR(kernel='rbf')

# Define the grid of hyperparameters to search
param_grid = {
    'C': [0.1, 1, 10, 100, 7000],
    'gamma': [0.001, 0.01, 0.1, 1],
    'epsilon': [0.0001, 0.01, 0.1, 0.2, 0.5]
}

# Perform grid search with cross-validation
grid_search = GridSearchCV(svr, param_grid, cv=5, scoring='r2', verbose=2, n_jobs=-1)
grid_search.fit(X_train, Y_train)

# Print the best parameters found by the grid search
print(f"Best parameters: {grid_search.best_params_}")

# Predict on the test set with the best model
best_svr = grid_search.best_estimator_
Y_pred = best_svr.predict(X_test)

# Evaluate the model
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)
print(f"Mean Squared Error: {mse}")
print(f"R^2 Score: {r2}")

# Scatter plot of actual vs predicted values
plt.figure(figsize=(10, 6))
plt.scatter(Y_test, Y_pred, color='blue', edgecolor='k', alpha=0.7)
plt.plot([Y_test.min(), Y_test.max()], [Y_test.min(), Y_test.max()], color='red', linewidth=2)
plt.xlabel('Actual Charges')
plt.ylabel('Predicted Charges')
plt.title('Actual vs Predicted Charges')
plt.show()
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# Best parameters: {'C': 7000, 'epsilon': 0.1, 'gamma': 0.1}
# Mean Squared Error: 22175655.946634322
# R^2 Score: 0.8503004283355664

# %%
#Saving these models

import pickle
import os
import joblib
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)  # Fit the scaler on the training data
# Save the models in the 'models' directory
os.makedirs('models', exist_ok=True)
# Save the scaler and its attributes
joblib.dump(scaler, 'models/scaler.joblib')
joblib.dump(scaler.mean_, 'models/scaler_mean_.joblib')
joblib.dump(scaler.scale_, 'models/scaler_scale_.joblib')


random_forest = RandomForestRegressor(n_estimators=100, random_state=42)
random_forest.fit(X_train, Y_train)
gradient_boosting = GradientBoostingRegressor(n_estimators=100, random_state=42)
gradient_boosting.fit(X_train, Y_train)
linear_regression = LinearRegression()
linear_regression.fit(X_train, Y_train)
svr = SVR(kernel='rbf', C=7000, epsilon= 0.1, gamma= 0.1)
svr.fit(X_train, Y_train)


joblib.dump(random_forest, 'models/random_forest.joblib')
joblib.dump(gradient_boosting, 'models/gradient_boosting.joblib')
joblib.dump(linear_regression, 'models/linear_regression.joblib')
joblib.dump(svr, 'models/svr.joblib')
# Out:
# ['models/svr.joblib']
